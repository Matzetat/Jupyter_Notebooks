# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # "My Jupyter Notebook in IBM Watson Studio"

# %% [markdown]
# MATHIAS TATJE
# Student

# %% [markdown]
# *I am interested in data science because I want to combine my  knowledge of statistics and IT together.*

# %% [markdown]
# ### The code in the following cell is a simple mathematical operation that calculates the number of hours in a typical year.
# ### 365 days multiplied by 24 hours per day results in an output of 8760 hours total.

# %%
365 * 24
# Out:
# 8760

# %% [markdown]
# ## 1. Table
# Row 1 Column 1  | Row 1 Column 2 | Row 1 Column 3
# --- | --- | ---
# Row 2 Column 1 | Row 2 Column 2 | Row 2 Column 3
# Row 3 Column 1 | Row 3 Column 2 | Row 3 Column 3
#
# ---
#
# ## 2. Hyperlinks
# [This link is supposed to take you to the coursera home page](www.coursera.org)
#
# ---
#
# ## 3. Blockquotes
# > This line is part of a block quote.
# > This line is part of it as well.
